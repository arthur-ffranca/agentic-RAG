# %%
pip install mcp
# Out:
# Requirement already satisfied: mcp in c:\users\otavi\anaconda3\lib\site-packages (1.27.1)
# Requirement already satisfied: anyio>=4.5 in c:\users\otavi\anaconda3\lib\site-packages (from mcp) (4.10.0)
# Requirement already satisfied: httpx-sse>=0.4 in c:\users\otavi\anaconda3\lib\site-packages (from mcp) (0.4.3)
# Requirement already satisfied: httpx<1.0.0,>=0.27.1 in c:\users\otavi\anaconda3\lib\site-packages (from mcp) (0.28.1)
# Requirement already satisfied: jsonschema>=4.20.0 in c:\users\otavi\anaconda3\lib\site-packages (from mcp) (4.25.0)
# Requirement already satisfied: pydantic-settings>=2.5.2 in c:\users\otavi\anaconda3\lib\site-packages (from mcp) (2.14.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.11.0 in c:\users\otavi\anaconda3\lib\site-packages (from mcp) (2.13.4)
# Requirement already satisfied: pyjwt>=2.10.1 in c:\users\otavi\anaconda3\lib\site-packages (from pyjwt[crypto]>=2.10.1->mcp) (2.10.1)
# Requirement already satisfied: python-multipart>=0.0.9 in c:\users\otavi\anaconda3\lib\site-packages (from mcp) (0.0.29)
# Requirement already satisfied: pywin32>=310 in c:\users\otavi\anaconda3\lib\site-packages (from mcp) (311)
# Requirement already satisfied: sse-starlette>=1.6.1 in c:\users\otavi\anaconda3\lib\site-packages (from mcp) (3.4.4)
# Requirement already satisfied: starlette>=0.27 in c:\users\otavi\anaconda3\lib\site-packages (from mcp) (1.0.1)
# Requirement already satisfied: typing-extensions>=4.9.0 in c:\users\otavi\anaconda3\lib\site-packages (from mcp) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.1 in c:\users\otavi\anaconda3\lib\site-packages (from mcp) (0.4.2)
# Requirement already satisfied: uvicorn>=0.31.1 in c:\users\otavi\anaconda3\lib\site-packages (from mcp) (0.47.0)
# Requirement already satisfied: certifi in c:\users\otavi\anaconda3\lib\site-packages (from httpx<1.0.0,>=0.27.1->mcp) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\otavi\anaconda3\lib\site-packages (from httpx<1.0.0,>=0.27.1->mcp) (1.0.9)
# Requirement already satisfied: idna in c:\users\otavi\anaconda3\lib\site-packages (from httpx<1.0.0,>=0.27.1->mcp) (3.18)
# Requirement already satisfied: h11>=0.16 in c:\users\otavi\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.27.1->mcp) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\otavi\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.11.0->mcp) (0.6.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\users\otavi\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.11.0->mcp) (2.46.4)
# Requirement already satisfied: sniffio>=1.1 in c:\users\otavi\anaconda3\lib\site-packages (from anyio>=4.5->mcp) (1.3.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\otavi\anaconda3\lib\site-packages (from jsonschema>=4.20.0->mcp) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\otavi\anaconda3\lib\site-packages (from jsonschema>=4.20.0->mcp) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\otavi\anaconda3\lib\site-packages (from jsonschema>=4.20.0->mcp) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\otavi\anaconda3\lib\site-packages (from jsonschema>=4.20.0->mcp) (0.28.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\otavi\anaconda3\lib\site-packages (from pydantic-settings>=2.5.2->mcp) (1.1.0)
# Requirement already satisfied: cryptography>=3.4.0 in c:\users\otavi\anaconda3\lib\site-packages (from pyjwt[crypto]>=2.10.1->mcp) (46.0.3)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\otavi\anaconda3\lib\site-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\otavi\anaconda3\lib\site-packages (from cffi>=2.0.0->cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp) (2.23)
# Requirement already satisfied: click>=7.0 in c:\users\otavi\anaconda3\lib\site-packages (from uvicorn>=0.31.1->mcp) (8.4.1)
# Requirement already satisfied: colorama in c:\users\otavi\anaconda3\lib\site-packages (from click>=7.0->uvicorn>=0.31.1->mcp) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install mcp pymongo python-dotenv
# Out:
# Requirement already satisfied: mcp in c:\users\otavi\anaconda3\lib\site-packages (1.27.1)
# Requirement already satisfied: pymongo in c:\users\otavi\anaconda3\lib\site-packages (4.17.0)
# Requirement already satisfied: python-dotenv in c:\users\otavi\anaconda3\lib\site-packages (1.1.0)
# Requirement already satisfied: anyio>=4.5 in c:\users\otavi\anaconda3\lib\site-packages (from mcp) (4.10.0)
# Requirement already satisfied: httpx-sse>=0.4 in c:\users\otavi\anaconda3\lib\site-packages (from mcp) (0.4.3)
# Requirement already satisfied: httpx<1.0.0,>=0.27.1 in c:\users\otavi\anaconda3\lib\site-packages (from mcp) (0.28.1)
# Requirement already satisfied: jsonschema>=4.20.0 in c:\users\otavi\anaconda3\lib\site-packages (from mcp) (4.25.0)
# Requirement already satisfied: pydantic-settings>=2.5.2 in c:\users\otavi\anaconda3\lib\site-packages (from mcp) (2.14.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.11.0 in c:\users\otavi\anaconda3\lib\site-packages (from mcp) (2.13.4)
# Requirement already satisfied: pyjwt>=2.10.1 in c:\users\otavi\anaconda3\lib\site-packages (from pyjwt[crypto]>=2.10.1->mcp) (2.10.1)
# Requirement already satisfied: python-multipart>=0.0.9 in c:\users\otavi\anaconda3\lib\site-packages (from mcp) (0.0.29)
# Requirement already satisfied: pywin32>=310 in c:\users\otavi\anaconda3\lib\site-packages (from mcp) (311)
# Requirement already satisfied: sse-starlette>=1.6.1 in c:\users\otavi\anaconda3\lib\site-packages (from mcp) (3.4.4)
# Requirement already satisfied: starlette>=0.27 in c:\users\otavi\anaconda3\lib\site-packages (from mcp) (1.0.1)
# Requirement already satisfied: typing-extensions>=4.9.0 in c:\users\otavi\anaconda3\lib\site-packages (from mcp) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.1 in c:\users\otavi\anaconda3\lib\site-packages (from mcp) (0.4.2)
# Requirement already satisfied: uvicorn>=0.31.1 in c:\users\otavi\anaconda3\lib\site-packages (from mcp) (0.47.0)
# Requirement already satisfied: certifi in c:\users\otavi\anaconda3\lib\site-packages (from httpx<1.0.0,>=0.27.1->mcp) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\otavi\anaconda3\lib\site-packages (from httpx<1.0.0,>=0.27.1->mcp) (1.0.9)
# Requirement already satisfied: idna in c:\users\otavi\anaconda3\lib\site-packages (from httpx<1.0.0,>=0.27.1->mcp) (3.18)
# Requirement already satisfied: h11>=0.16 in c:\users\otavi\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.27.1->mcp) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\otavi\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.11.0->mcp) (0.6.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\users\otavi\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.11.0->mcp) (2.46.4)
# Requirement already satisfied: dnspython<3.0.0,>=2.6.1 in c:\users\otavi\anaconda3\lib\site-packages (from pymongo) (2.8.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\otavi\anaconda3\lib\site-packages (from anyio>=4.5->mcp) (1.3.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\otavi\anaconda3\lib\site-packages (from jsonschema>=4.20.0->mcp) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\otavi\anaconda3\lib\site-packages (from jsonschema>=4.20.0->mcp) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\otavi\anaconda3\lib\site-packages (from jsonschema>=4.20.0->mcp) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\otavi\anaconda3\lib\site-packages (from jsonschema>=4.20.0->mcp) (0.28.0)
# Requirement already satisfied: cryptography>=3.4.0 in c:\users\otavi\anaconda3\lib\site-packages (from pyjwt[crypto]>=2.10.1->mcp) (46.0.3)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\otavi\anaconda3\lib\site-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\otavi\anaconda3\lib\site-packages (from cffi>=2.0.0->cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp) (2.23)
# Requirement already satisfied: click>=7.0 in c:\users\otavi\anaconda3\lib\site-packages (from uvicorn>=0.31.1->mcp) (8.4.1)
# Requirement already satisfied: colorama in c:\users\otavi\anaconda3\lib\site-packages (from click>=7.0->uvicorn>=0.31.1->mcp) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
from os import getenv
from dotenv import load_dotenv
from pymongo import MongoClient
from mcp.server.fastmcp import FastMCP

load_dotenv()

mcp = FastMCP("mongo-mcp")

client = MongoClient(getenv("MONGO_URI"))

# %%
@mcp.tool()
def list_databases() -> list[str]:
    """Lista os bancos disponiveis no MongoDB."""
    return client.list_database_names()

# %%
@mcp.tool()
def list_collections(database: str) -> list[str]:
    """Lista as collections de um database."""
    db = client[database]
    return db.list_collection_names()

# %%
@mcp.tool()
def count_documents_mongo(database: str, collection: str, filtro: dict | None = None) -> int:
    col = client[database][collection]
    return col.count_documents(filtro or {})

# %%
@mcp.tool()
def find_documents_mongo(database: str, collection: str, filtro: dict, limite: int = 5) -> list[dict]:
    """Busca documentos em uma collection usando um filtro MongoDB."""
    limite = min(limite, 20)
    db = client[database]
    col = db[collection]

    docs = list(col.find(filtro).limit(limite))

    for doc in docs:
        doc["_id"] = str(doc["_id"])

    return docs


if __name__ == "__main__":
    mcp.run()
# Out:
# [07/07/26 14:16:34] WARNING  Tool already exists: buscar_documentos_mongo                        ]8;id=2912581;file://c:\Users\otavi\anaconda3\Lib\site-packages\mcp\server\fastmcp\tools\tool_manager.py\tool_manager.py]8;;\:]8;id=2912582;file://c:\Users\otavi\anaconda3\Lib\site-packages\mcp\server\fastmcp\tools\tool_manager.py#70\70]8;;\
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[9], line 17
#      13     return docs
#      16 if __name__ == "__main__":
# ---> 17     mcp.run()
#
# File c:\Users\otavi\anaconda3\Lib\site-packages\mcp\server\fastmcp\server.py:296, in FastMCP.run(self, transport, mount_path)
#     294 match transport:
#     295     case "stdio":
# --> 296         anyio.run(self.run_stdio_async)
#     297     case "sse":  # pragma: no cover
#     298         anyio.run(lambda: self.run_sse_async(mount_path))
#
# File c:\Users\otavi\anaconda3\Lib\site-packages\anyio\_core\_eventloop.py:59, in run(func, backend, backend_options, *args)
#      57     pass
#      58 else:
# ---> 59     raise RuntimeError(f"Already running {asynclib_name} in this thread")
#      61 try:
#      62     async_backend = get_async_backend(backend)
#
# RuntimeError: Already running asyncio in this thread

# %%
pip install chromadb
# Out:
# Requirement already satisfied: chromadb in c:\users\otavi\anaconda3\lib\site-packages (1.5.9)
# Requirement already satisfied: build>=1.0.3 in c:\users\otavi\anaconda3\lib\site-packages (from chromadb) (1.5.0)
# Requirement already satisfied: pydantic>=2.0 in c:\users\otavi\anaconda3\lib\site-packages (from chromadb) (2.13.4)
# Requirement already satisfied: pydantic-settings>=2.0 in c:\users\otavi\anaconda3\lib\site-packages (from chromadb) (2.14.2)
# Requirement already satisfied: pybase64>=1.4.1 in c:\users\otavi\anaconda3\lib\site-packages (from chromadb) (1.4.3)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\otavi\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.47.0)
# Requirement already satisfied: numpy>=1.22.5 in c:\users\otavi\anaconda3\lib\site-packages (from chromadb) (2.3.5)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\otavi\anaconda3\lib\site-packages (from chromadb) (4.15.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\otavi\anaconda3\lib\site-packages (from chromadb) (1.27.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\otavi\anaconda3\lib\site-packages (from chromadb) (1.43.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\otavi\anaconda3\lib\site-packages (from chromadb) (1.43.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\otavi\anaconda3\lib\site-packages (from chromadb) (1.43.0)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\otavi\anaconda3\lib\site-packages (from chromadb) (0.22.2)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\otavi\anaconda3\lib\site-packages (from chromadb) (0.51.1)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\otavi\anaconda3\lib\site-packages (from chromadb) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\otavi\anaconda3\lib\site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\users\otavi\anaconda3\lib\site-packages (from chromadb) (7.1.0)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\otavi\anaconda3\lib\site-packages (from chromadb) (1.82.0)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\otavi\anaconda3\lib\site-packages (from chromadb) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\otavi\anaconda3\lib\site-packages (from chromadb) (0.24.2)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\otavi\anaconda3\lib\site-packages (from chromadb) (36.0.2)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\otavi\anaconda3\lib\site-packages (from chromadb) (9.1.2)
# Requirement already satisfied: pyyaml>=6.0.0 in c:\users\otavi\anaconda3\lib\site-packages (from chromadb) (6.0.3)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\otavi\anaconda3\lib\site-packages (from chromadb) (5.2.1)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\otavi\anaconda3\lib\site-packages (from chromadb) (3.11.9)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\otavi\anaconda3\lib\site-packages (from chromadb) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in c:\users\otavi\anaconda3\lib\site-packages (from chromadb) (15.0.0)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\users\otavi\anaconda3\lib\site-packages (from chromadb) (4.25.0)
# Requirement already satisfied: packaging>=24.0 in c:\users\otavi\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (25.0)
# Requirement already satisfied: pyproject_hooks in c:\users\otavi\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: colorama in c:\users\otavi\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: anyio in c:\users\otavi\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (4.10.0)
# Requirement already satisfied: certifi in c:\users\otavi\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\otavi\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (1.0.9)
# Requirement already satisfied: idna in c:\users\otavi\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (3.18)
# Requirement already satisfied: h11>=0.16 in c:\users\otavi\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\otavi\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\otavi\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\otavi\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\otavi\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.28.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\otavi\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\otavi\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\otavi\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests in c:\users\otavi\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.32.5)
# Requirement already satisfied: requests-oauthlib in c:\users\otavi\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: urllib3!=2.6.0,>=1.24.2 in c:\users\otavi\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.5.0)
# Requirement already satisfied: durationpy>=0.7 in c:\users\otavi\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: aiohttp<4.0.0,>=3.13.5 in c:\users\otavi\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (3.14.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\otavi\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\otavi\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\otavi\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\otavi\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\otavi\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\otavi\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb) (1.22.0)
# Requirement already satisfied: flatbuffers in c:\users\otavi\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (25.12.19)
# Requirement already satisfied: protobuf>=4.25.8 in c:\users\otavi\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (6.33.6)
# Requirement already satisfied: googleapis-common-protos~=1.57 in c:\users\otavi\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.75.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.43.0 in c:\users\otavi\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.43.0)
# Requirement already satisfied: opentelemetry-proto==1.43.0 in c:\users\otavi\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.43.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.64b0 in c:\users\otavi\anaconda3\lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.64b0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\otavi\anaconda3\lib\site-packages (from pydantic>=2.0->chromadb) (0.6.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\users\otavi\anaconda3\lib\site-packages (from pydantic>=2.0->chromadb) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\otavi\anaconda3\lib\site-packages (from pydantic>=2.0->chromadb) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\otavi\anaconda3\lib\site-packages (from pydantic-settings>=2.0->chromadb) (1.1.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\otavi\anaconda3\lib\site-packages (from rich>=10.11.0->chromadb) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\otavi\anaconda3\lib\site-packages (from rich>=10.11.0->chromadb) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\otavi\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in c:\users\otavi\anaconda3\lib\site-packages (from tokenizers>=0.13.2->chromadb) (1.20.1)
# Requirement already satisfied: click>=8.4.0 in c:\users\otavi\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (8.4.1)
# Requirement already satisfied: filelock>=3.10.0 in c:\users\otavi\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\otavi\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2025.10.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in c:\users\otavi\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (1.5.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\otavi\anaconda3\lib\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\otavi\anaconda3\lib\site-packages (from typer>=0.9.0->chromadb) (0.0.4)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\otavi\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.7.1)
# Requirement already satisfied: watchfiles>=0.20 in c:\users\otavi\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.2.0)
# Requirement already satisfied: websockets>=10.4 in c:\users\otavi\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\otavi\anaconda3\lib\site-packages (from anyio->httpx>=0.27.0->chromadb) (1.3.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\otavi\anaconda3\lib\site-packages (from requests->kubernetes>=28.1.0->chromadb) (3.4.4)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\otavi\anaconda3\lib\site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install sentence-transformers faiss-cpu beautifulsoup4 pypdf langchain
# Out:
# Requirement already satisfied: sentence-transformers in c:\users\otavi\anaconda3\lib\site-packages (5.6.0)
# Requirement already satisfied: faiss-cpu in c:\users\otavi\anaconda3\lib\site-packages (1.14.3)
# Requirement already satisfied: beautifulsoup4 in c:\users\otavi\anaconda3\lib\site-packages (4.13.5)
# Requirement already satisfied: pypdf in c:\users\otavi\anaconda3\lib\site-packages (6.12.1)
# Requirement already satisfied: langchain in c:\users\otavi\anaconda3\lib\site-packages (1.3.11)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in c:\users\otavi\anaconda3\lib\site-packages (from sentence-transformers) (5.12.1)
# Requirement already satisfied: huggingface-hub>=0.23.0 in c:\users\otavi\anaconda3\lib\site-packages (from sentence-transformers) (1.20.1)
# Requirement already satisfied: torch>=1.11.0 in c:\users\otavi\anaconda3\lib\site-packages (from sentence-transformers) (2.12.1)
# Requirement already satisfied: numpy>=1.20.0 in c:\users\otavi\anaconda3\lib\site-packages (from sentence-transformers) (2.3.5)
# Requirement already satisfied: scikit-learn>=0.22.0 in c:\users\otavi\anaconda3\lib\site-packages (from sentence-transformers) (1.7.2)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\otavi\anaconda3\lib\site-packages (from sentence-transformers) (1.16.3)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\otavi\anaconda3\lib\site-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: tqdm>=4.0.0 in c:\users\otavi\anaconda3\lib\site-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\otavi\anaconda3\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\otavi\anaconda3\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (6.0.3)
# Requirement already satisfied: regex>=2025.10.22 in c:\users\otavi\anaconda3\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2026.5.9)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\otavi\anaconda3\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.22.2)
# Requirement already satisfied: typer in c:\users\otavi\anaconda3\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.24.2)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\otavi\anaconda3\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.8.0)
# Requirement already satisfied: click>=8.4.0 in c:\users\otavi\anaconda3\lib\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (8.4.1)
# Requirement already satisfied: filelock>=3.10.0 in c:\users\otavi\anaconda3\lib\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\otavi\anaconda3\lib\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (2025.10.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in c:\users\otavi\anaconda3\lib\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (1.5.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\otavi\anaconda3\lib\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (0.28.1)
# Requirement already satisfied: anyio in c:\users\otavi\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (4.10.0)
# Requirement already satisfied: certifi in c:\users\otavi\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\otavi\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (1.0.9)
# Requirement already satisfied: idna in c:\users\otavi\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (3.18)
# Requirement already satisfied: h11>=0.16 in c:\users\otavi\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (0.16.0)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\otavi\anaconda3\lib\site-packages (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in c:\users\otavi\anaconda3\lib\site-packages (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\otavi\anaconda3\lib\site-packages (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (0.0.4)
# Requirement already satisfied: soupsieve>1.2 in c:\users\otavi\anaconda3\lib\site-packages (from beautifulsoup4) (2.5)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.7 in c:\users\otavi\anaconda3\lib\site-packages (from langchain) (1.4.8)
# Requirement already satisfied: langgraph<1.3.0,>=1.2.5 in c:\users\otavi\anaconda3\lib\site-packages (from langchain) (1.2.8)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\otavi\anaconda3\lib\site-packages (from langchain) (2.13.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\otavi\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.4.7->langchain) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in c:\users\otavi\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.4.7->langchain) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\otavi\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.4.7->langchain) (0.9.8)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\otavi\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.4.7->langchain) (9.1.2)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\otavi\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.4.7->langchain) (0.16.2)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\otavi\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.7->langchain) (3.0.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in c:\users\otavi\anaconda3\lib\site-packages (from langgraph<1.3.0,>=1.2.5->langchain) (4.1.1)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in c:\users\otavi\anaconda3\lib\site-packages (from langgraph<1.3.0,>=1.2.5->langchain) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.5.0,>=0.4.2 in c:\users\otavi\anaconda3\lib\site-packages (from langgraph<1.3.0,>=1.2.5->langchain) (0.4.2)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\otavi\anaconda3\lib\site-packages (from langgraph<1.3.0,>=1.2.5->langchain) (3.8.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\otavi\anaconda3\lib\site-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.5->langchain) (1.12.2)
# Requirement already satisfied: orjson>=3.11.5 in c:\users\otavi\anaconda3\lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (3.11.9)
# Requirement already satisfied: websockets<16,>=14 in c:\users\otavi\anaconda3\lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (15.0.1)
# Requirement already satisfied: distro>=1.7.0 in c:\users\otavi\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain) (1.9.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\otavi\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\otavi\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain) (2.32.5)
# Requirement already satisfied: sniffio>=1.1 in c:\users\otavi\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain) (1.3.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\otavi\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain) (0.24.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\otavi\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\users\otavi\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\otavi\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: colorama in c:\users\otavi\anaconda3\lib\site-packages (from click>=8.4.0->huggingface-hub>=0.23.0->sentence-transformers) (0.4.6)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\otavi\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\otavi\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain) (2.5.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\otavi\anaconda3\lib\site-packages (from rich>=12.3.0->typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\otavi\anaconda3\lib\site-packages (from rich>=12.3.0->typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\otavi\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (0.1.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\otavi\anaconda3\lib\site-packages (from scikit-learn>=0.22.0->sentence-transformers) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\otavi\anaconda3\lib\site-packages (from scikit-learn>=0.22.0->sentence-transformers) (3.5.0)
# Requirement already satisfied: setuptools<82 in c:\users\otavi\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\otavi\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\otavi\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.5)
# Requirement already satisfied: jinja2 in c:\users\otavi\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\otavi\anaconda3\lib\site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\otavi\anaconda3\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install langchain langchain-text-splitters bs4 requests
# Out:
# Requirement already satisfied: langchain in c:\users\otavi\anaconda3\lib\site-packages (1.3.11)
# Requirement already satisfied: langchain-text-splitters in c:\users\otavi\anaconda3\lib\site-packages (1.1.2)
# Requirement already satisfied: bs4 in c:\users\otavi\anaconda3\lib\site-packages (0.0.2)
# Requirement already satisfied: requests in c:\users\otavi\anaconda3\lib\site-packages (2.32.5)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.7 in c:\users\otavi\anaconda3\lib\site-packages (from langchain) (1.4.8)
# Requirement already satisfied: langgraph<1.3.0,>=1.2.5 in c:\users\otavi\anaconda3\lib\site-packages (from langchain) (1.2.8)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\otavi\anaconda3\lib\site-packages (from langchain) (2.13.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\otavi\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.4.7->langchain) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in c:\users\otavi\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.4.7->langchain) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\otavi\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.4.7->langchain) (0.9.8)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\otavi\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.4.7->langchain) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\otavi\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.4.7->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\otavi\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.4.7->langchain) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\otavi\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.4.7->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\otavi\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.4.7->langchain) (0.16.2)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\otavi\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.7->langchain) (3.0.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in c:\users\otavi\anaconda3\lib\site-packages (from langgraph<1.3.0,>=1.2.5->langchain) (4.1.1)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in c:\users\otavi\anaconda3\lib\site-packages (from langgraph<1.3.0,>=1.2.5->langchain) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.5.0,>=0.4.2 in c:\users\otavi\anaconda3\lib\site-packages (from langgraph<1.3.0,>=1.2.5->langchain) (0.4.2)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\otavi\anaconda3\lib\site-packages (from langgraph<1.3.0,>=1.2.5->langchain) (3.8.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\otavi\anaconda3\lib\site-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.5->langchain) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\otavi\anaconda3\lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in c:\users\otavi\anaconda3\lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (3.11.9)
# Requirement already satisfied: websockets<16,>=14 in c:\users\otavi\anaconda3\lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (15.0.1)
# Requirement already satisfied: anyio>=3.5.0 in c:\users\otavi\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain) (4.10.0)
# Requirement already satisfied: distro>=1.7.0 in c:\users\otavi\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain) (1.9.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\otavi\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain) (1.0.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\otavi\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain) (1.3.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\otavi\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain) (0.24.0)
# Requirement already satisfied: certifi in c:\users\otavi\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\otavi\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (1.0.9)
# Requirement already satisfied: idna in c:\users\otavi\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (3.18)
# Requirement already satisfied: h11>=0.16 in c:\users\otavi\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\otavi\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\users\otavi\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\otavi\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\otavi\anaconda3\lib\site-packages (from bs4) (4.13.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\otavi\anaconda3\lib\site-packages (from requests) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\otavi\anaconda3\lib\site-packages (from requests) (2.5.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\otavi\anaconda3\lib\site-packages (from beautifulsoup4->bs4) (2.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install langchain langchain-community pymupdf
# Out:
# Requirement already satisfied: langchain in c:\users\otavi\anaconda3\lib\site-packages (1.3.11)
# Requirement already satisfied: langchain-community in c:\users\otavi\anaconda3\lib\site-packages (0.4.2)
# Requirement already satisfied: pymupdf in c:\users\otavi\anaconda3\lib\site-packages (1.28.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.7 in c:\users\otavi\anaconda3\lib\site-packages (from langchain) (1.4.8)
# Requirement already satisfied: langgraph<1.3.0,>=1.2.5 in c:\users\otavi\anaconda3\lib\site-packages (from langchain) (1.2.8)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\otavi\anaconda3\lib\site-packages (from langchain) (2.13.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\otavi\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.4.7->langchain) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in c:\users\otavi\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.4.7->langchain) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\otavi\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.4.7->langchain) (0.9.8)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\otavi\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.4.7->langchain) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\otavi\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.4.7->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\otavi\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.4.7->langchain) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\otavi\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.4.7->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\otavi\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.4.7->langchain) (0.16.2)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\otavi\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.7->langchain) (3.0.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in c:\users\otavi\anaconda3\lib\site-packages (from langgraph<1.3.0,>=1.2.5->langchain) (4.1.1)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in c:\users\otavi\anaconda3\lib\site-packages (from langgraph<1.3.0,>=1.2.5->langchain) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.5.0,>=0.4.2 in c:\users\otavi\anaconda3\lib\site-packages (from langgraph<1.3.0,>=1.2.5->langchain) (0.4.2)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\otavi\anaconda3\lib\site-packages (from langgraph<1.3.0,>=1.2.5->langchain) (3.8.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\otavi\anaconda3\lib\site-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.5->langchain) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\otavi\anaconda3\lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in c:\users\otavi\anaconda3\lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (3.11.9)
# Requirement already satisfied: websockets<16,>=14 in c:\users\otavi\anaconda3\lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (15.0.1)
# Requirement already satisfied: anyio>=3.5.0 in c:\users\otavi\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain) (4.10.0)
# Requirement already satisfied: distro>=1.7.0 in c:\users\otavi\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain) (1.9.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\otavi\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\otavi\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain) (2.32.5)
# Requirement already satisfied: sniffio>=1.1 in c:\users\otavi\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain) (1.3.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\otavi\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain) (0.24.0)
# Requirement already satisfied: certifi in c:\users\otavi\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\otavi\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (1.0.9)
# Requirement already satisfied: idna in c:\users\otavi\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (3.18)
# Requirement already satisfied: h11>=0.16 in c:\users\otavi\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\otavi\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\users\otavi\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\otavi\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\otavi\anaconda3\lib\site-packages (from langchain-community) (3.14.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\otavi\anaconda3\lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.7 in c:\users\otavi\anaconda3\lib\site-packages (from langchain-community) (1.0.8)
# Requirement already satisfied: numpy>=2.1.0 in c:\users\otavi\anaconda3\lib\site-packages (from langchain-community) (2.3.5)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\users\otavi\anaconda3\lib\site-packages (from langchain-community) (2.14.2)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in c:\users\otavi\anaconda3\lib\site-packages (from langchain-community) (2.0.43)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\otavi\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\otavi\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\otavi\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\otavi\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\otavi\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\otavi\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\otavi\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.22.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.2 in c:\users\otavi\anaconda3\lib\site-packages (from langchain-classic<2.0.0,>=1.0.7->langchain-community) (1.1.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\otavi\anaconda3\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.1.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\otavi\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\otavi\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain) (2.5.0)
# Requirement already satisfied: greenlet>=1 in c:\users\otavi\anaconda3\lib\site-packages (from sqlalchemy<3.0.0,>=1.4.0->langchain-community) (3.2.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
from pathlib import Path

# %%
from langchain_community.document_loaders import PyMuPDFLoader

Path = r'C:/Users/otavi/OneDrive/Desktop/virtologia.pdf'

loader = PyMuPDFLoader(Path)
docs = loader.load()

print(len(docs))
print(docs[0].page_content[:500])
print(docs[0].metadata)
# Out:
# C:\Users\otavi\AppData\Local\Temp\ipykernel_30988\694584870.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import PyMuPDFLoader
# 664
# Fundamentos da
# Virtologia
# Fundamentos da Virtologia_04/02/25.indd   1
# Fundamentos da Virtologia_04/02/25.indd   1
# 04/02/25   09:30
# 04/02/25   09:30
# {'producer': 'Adobe PDF Library 17.0', 'creator': 'Adobe InDesign 18.5 (Macintosh)', 'creationdate': '2025-02-04T09:30:39-03:00', 'source': 'C:/Users/otavi/OneDrive/Desktop/virtologia.pdf', 'file_path': 'C:/Users/otavi/OneDrive/Desktop/virtologia.pdf', 'total_pages': 664, 'format': 'PDF 1.6', 'title': 'Fundamentos da Virtologia_04/02/25.indd', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-02-04T09:31:04-03:00', 'trapped': '', 'modDate': "D:20250204093104-03'00'", 'creationDate': "D:20250204093039-03'00'", 'page': 0}

# %%
pip install langchain-text-splitters
# Out:
# Requirement already satisfied: langchain-text-splitters in c:\users\otavi\anaconda3\lib\site-packages (1.1.2)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.31 in c:\users\otavi\anaconda3\lib\site-packages (from langchain-text-splitters) (1.4.8)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\otavi\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in c:\users\otavi\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\otavi\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.9.8)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\otavi\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (25.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\otavi\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2.13.4)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\otavi\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\otavi\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\otavi\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\otavi\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.16.2)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\otavi\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (3.0.0)
# Requirement already satisfied: anyio>=3.5.0 in c:\users\otavi\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (4.10.0)
# Requirement already satisfied: distro>=1.7.0 in c:\users\otavi\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\otavi\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\otavi\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\otavi\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\otavi\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2.32.5)
# Requirement already satisfied: sniffio>=1.1 in c:\users\otavi\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (1.3.0)
# Requirement already satisfied: websockets>=15.0 in c:\users\otavi\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (15.0.1)
# Requirement already satisfied: xxhash>=3.0.0 in c:\users\otavi\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (3.8.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\otavi\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.24.0)
# Requirement already satisfied: certifi in c:\users\otavi\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\otavi\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (1.0.9)
# Requirement already satisfied: idna in c:\users\otavi\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (3.18)
# Requirement already satisfied: h11>=0.16 in c:\users\otavi\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\otavi\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.6.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\users\otavi\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\otavi\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\otavi\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\otavi\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

splitter = RecursiveCharacterTextSplitter(
    chunk_size=1500,
    chunk_overlap=250,
)

chunks = splitter.split_documents(docs)

# %%
for i, chunk in enumerate(chunks[10:15]):
    print(f"\n--- CHUNK {i} ---")
    print(chunk.page_content[:1500])
# Out:
# --- CHUNK 0 ---
# 9
# INTRODUÇÃO
# A
# Virtologia é uma abordagem abrangente e prática para o desen-
# volvimento humano, que se baseia em pilares fundamentais: as
# faixas de evolução, o orgulho como raiz das neuroses, o inconsciente
# booleano, os grupos de necessidades humanas e a formação da perso-
# nalidade por meio da neuroplasticidade. Com esses elementos, sob a
# visão da Virtologia, ofereço um caminho claro que não apenas explora
# o autoconhecimento, mas que foca diretamente na construção de uma
# personalidade com competências sólidas. Neste livro conheceremos mais
# sobre essa abordagem e as suas práticas, com o objetivo de capacitar o
# indivíduo a lidar com qualquer nível de trauma e desafios emocionais
# por meio de técnicas únicas e comprovadas.
# Para a Virtologia, a formação da personalidade é um aspecto central
# do desenvolvimento humano. Ao contrário das abordagens que buscam
# explorar o inconsciente em busca de conteúdos desconhecidos, na abor-
# dagem da Virtologia temos a construção de competências para o Ego. O
# indivíduo não lida com o “não-sabido” porque o seu Ego carece de habi-
# lidades para enfrentá-lo. Dessa forma, ao fortalecer a personalidade por
# meio da prática de Virtudes, utilizamos a neuroplasticidade para criar co-
# nexões neurais e aumentar a capacidade de enfrentamento e adaptação
# do indivíduo. Essa abordagem permite que o ser humano construa uma
# personalidade resiliente e equilibrada, que possa lidar com situações de
#
# --- CHUNK 1 ---
# nexões neurais e aumentar a capacidade de enfrentamento e adaptação
# do indivíduo. Essa abordagem permite que o ser humano construa uma
# personalidade resiliente e equilibrada, que possa lidar com situações de
# trauma e conflito de maneira mais consciente, resolvendo o seu problema.
# A neuroplasticidade é outro pilar essencial da Virtologia. Vejo a neuro-
# plasticidade como um recurso fundamental para o autodesenvolvimento
# Fundamentos da Virtologia_04/02/25.indd   9
# Fundamentos da Virtologia_04/02/25.indd   9
# 04/02/25   09:30
# 04/02/25   09:30
#
# --- CHUNK 2 ---
# 10
# Fundamentos da Virtologia
# e a reestruturação do Ego, permitindo que o indivíduo modifique as
# suas respostas e reações emocionais. Ao desenvolver Virtudes como hu-
# mildade, paciência e responsabilidade, o ser humano fortalece circuitos
# neurais que o capacitam a enfrentar os desafios da vida com uma base
# sólida e adaptável. Esse processo é diferente de abordagens terapêuticas
# tradicionais — como a psicanálise, que se baseia na catarse e na revelação
# de conteúdos reprimidos. A Virtologia, ao invés disso, utiliza a prática de
# Virtudes para criar uma transformação gradual e permanente no cérebro
# e na personalidade.
# Na Virtologia, as faixas de evolução refletem os estágios de desen-
# volvimento pelos quais o ser humano passa, desde os níveis mais básicos
# de sobrevivência até os estágios mais elevados de autotranscendência e
# conexão com o todo. As necessidades humanas são organizadas em gru-
# pos de necessidades que se ajustam de acordo com o estágio evolutivo do
# indivíduo. Em estágios primitivos, as necessidades básicas de segurança e
# fisiologia são dominantes, porém, conforme o indivíduo evolui, surgem
# necessidades mais complexas, como propósito e introspecção. Esse mo-
# delo dinâmico permite que o ser humano compreenda as suas necessi-
# dades com clareza e se desenvolva de maneira equilibrada, criando uma
# personalidade autossuficiente.
# O orgulho é o núcleo das neuroses humanas. Considero o orgulho
# — essa necessidade primitiva de ser importante e aceito — como o prin-
#
# --- CHUNK 3 ---
# dades com clareza e se desenvolva de maneira equilibrada, criando uma
# personalidade autossuficiente.
# O orgulho é o núcleo das neuroses humanas. Considero o orgulho
# — essa necessidade primitiva de ser importante e aceito — como o prin-
# cipal gerador de conflitos internos e resistência ao crescimento. Somado
# a isso, o conceito do inconsciente booleano propõe que a mente incons-
# ciente opera de maneira matemática, na qual experiências semelhantes
# são somadas e reforçadas. Esse modelo permite que a Virtologia interpre-
# te as neuroses e traumas de maneira estruturada, e utilize essa compreen-
# são para criar intervenções que ajudam o indivíduo a superar o orgulho
# e a reestruturar a sua mente de forma saudável e adaptativa.
# As dinâmicas da vida podem ser compreendidas e superadas a par-
# tir dessa lógica booleana, denominada de inconsciente booleano. Nesse
# modelo, o cérebro humano funciona como um processador que busca,
# inconscientemente, cobrir lacunas emocionais ou faltas. O inconsciente
# Fundamentos da Virtologia_04/02/25.indd   10
# Fundamentos da Virtologia_04/02/25.indd   10
# 04/02/25   09:30
# 04/02/25   09:30
#
# --- CHUNK 4 ---
# 11
# Introdução
# calcula padrões de comportamento e projeção que, muitas vezes, repetem
# experiências passadas de rejeição, abandono ou carência, em uma tenta-
# tiva de suprir essas necessidades.
# Com o que desenvolvi, a Virtologia se aprofunda nesse conceito de
# “falta”, interpretando-o como o núcleo dos processos inconscientes que
# governam o comportamento humano. A falta é uma condição prévia e
# fundamental da existência humana, que estrutura o desejo e a subjetivi-
# dade, sendo revelada e intensificada — mas não criada — pelas experiên-
# cias traumáticas e outros eventos significativos na vida de uma pessoa.
# A ideia de que a falta corresponde à falta de unidade reflete a busca do
# indivíduo por completude e plenitude. A Virtologia vê essa busca como
# central para o desenvolvimento psíquico e emocional, na qual o reconhe-
# cimento dessa falta e o esforço para superá-la moldam a identidade e a
# personalidade. A completude e plenitude, nesse sentido, são metas que
# orientam o desejo e as ações do sujeito, embora a falta seja uma condição
# inerente e constante na experiência humana.
# Ao compreender a matemática que rege esse processo, ofereço atra-
# vés da Virtologia uma abordagem eficaz para o tratamento de transtornos
# mentais e emocionais, permitindo que o indivíduo se liberte dos padrões
# repetitivos que perpetuam as suas neuroses.
# No cerne da Virtologia estão as Virtudes — qualidades humanas que
# transcendem a sobrevivência e o instinto primitivo de busca por aceitação.

# %%
pip install langchain-chroma langchain-huggingface
# Out:
# Requirement already satisfied: langchain-chroma in c:\users\otavi\anaconda3\lib\site-packages (1.1.0)
# Requirement already satisfied: langchain-huggingface in c:\users\otavi\anaconda3\lib\site-packages (1.2.2)
# Requirement already satisfied: chromadb<2.0.0,>=1.3.5 in c:\users\otavi\anaconda3\lib\site-packages (from langchain-chroma) (1.5.9)
# Requirement already satisfied: langchain-core<2.0.0,>=1.1.3 in c:\users\otavi\anaconda3\lib\site-packages (from langchain-chroma) (1.4.8)
# Requirement already satisfied: numpy>=2.1.0 in c:\users\otavi\anaconda3\lib\site-packages (from langchain-chroma) (2.3.5)
# Requirement already satisfied: build>=1.0.3 in c:\users\otavi\anaconda3\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.5.0)
# Requirement already satisfied: pydantic>=2.0 in c:\users\otavi\anaconda3\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.13.4)
# Requirement already satisfied: pydantic-settings>=2.0 in c:\users\otavi\anaconda3\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.14.2)
# Requirement already satisfied: pybase64>=1.4.1 in c:\users\otavi\anaconda3\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.4.3)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\otavi\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.47.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\otavi\anaconda3\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (4.15.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\otavi\anaconda3\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.27.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\otavi\anaconda3\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.43.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\otavi\anaconda3\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.43.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\otavi\anaconda3\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.43.0)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\otavi\anaconda3\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.22.2)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\otavi\anaconda3\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.51.1)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\otavi\anaconda3\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\otavi\anaconda3\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\users\otavi\anaconda3\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (7.1.0)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\otavi\anaconda3\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.82.0)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\otavi\anaconda3\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\otavi\anaconda3\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.24.2)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\otavi\anaconda3\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (36.0.2)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\otavi\anaconda3\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (9.1.2)
# Requirement already satisfied: pyyaml>=6.0.0 in c:\users\otavi\anaconda3\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (6.0.3)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\otavi\anaconda3\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (5.2.1)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\otavi\anaconda3\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (3.11.9)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\otavi\anaconda3\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in c:\users\otavi\anaconda3\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (15.0.0)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\users\otavi\anaconda3\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (4.25.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\otavi\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.1.3->langchain-chroma) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in c:\users\otavi\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.1.3->langchain-chroma) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\otavi\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.1.3->langchain-chroma) (0.9.8)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\otavi\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.1.3->langchain-chroma) (25.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\otavi\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.1.3->langchain-chroma) (0.16.2)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\otavi\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (3.0.0)
# Requirement already satisfied: anyio>=3.5.0 in c:\users\otavi\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (4.10.0)
# Requirement already satisfied: distro>=1.7.0 in c:\users\otavi\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (1.9.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\otavi\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\otavi\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (2.32.5)
# Requirement already satisfied: sniffio>=1.1 in c:\users\otavi\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (1.3.0)
# Requirement already satisfied: websockets>=15.0 in c:\users\otavi\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (15.0.1)
# Requirement already satisfied: xxhash>=3.0.0 in c:\users\otavi\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (3.8.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\otavi\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (0.24.0)
# Requirement already satisfied: certifi in c:\users\otavi\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\otavi\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.0.9)
# Requirement already satisfied: idna in c:\users\otavi\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (3.18)
# Requirement already satisfied: h11>=0.16 in c:\users\otavi\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\otavi\anaconda3\lib\site-packages (from pydantic>=2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.6.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\users\otavi\anaconda3\lib\site-packages (from pydantic>=2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\otavi\anaconda3\lib\site-packages (from pydantic>=2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.4.2)
# Requirement already satisfied: huggingface-hub<2.0.0,>=0.33.4 in c:\users\otavi\anaconda3\lib\site-packages (from langchain-huggingface) (1.20.1)
# Requirement already satisfied: click>=8.4.0 in c:\users\otavi\anaconda3\lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (8.4.1)
# Requirement already satisfied: filelock>=3.10.0 in c:\users\otavi\anaconda3\lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\otavi\anaconda3\lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (2025.10.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in c:\users\otavi\anaconda3\lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (1.5.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\otavi\anaconda3\lib\site-packages (from typer>=0.9.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\otavi\anaconda3\lib\site-packages (from typer>=0.9.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.0.4)
# Requirement already satisfied: pyproject_hooks in c:\users\otavi\anaconda3\lib\site-packages (from build>=1.0.3->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.2.0)
# Requirement already satisfied: colorama in c:\users\otavi\anaconda3\lib\site-packages (from build>=1.0.3->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.4.6)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\otavi\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\otavi\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\otavi\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\otavi\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.28.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\otavi\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\otavi\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.9.0.post0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\otavi\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.8.0)
# Requirement already satisfied: requests-oauthlib in c:\users\otavi\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.0.0)
# Requirement already satisfied: urllib3!=2.6.0,>=1.24.2 in c:\users\otavi\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.5.0)
# Requirement already satisfied: durationpy>=0.7 in c:\users\otavi\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.10)
# Requirement already satisfied: aiohttp<4.0.0,>=3.13.5 in c:\users\otavi\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (3.14.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\otavi\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\otavi\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\otavi\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\otavi\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\otavi\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\otavi\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.22.0)
# Requirement already satisfied: flatbuffers in c:\users\otavi\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb<2.0.0,>=1.3.5->langchain-chroma) (25.12.19)
# Requirement already satisfied: protobuf>=4.25.8 in c:\users\otavi\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb<2.0.0,>=1.3.5->langchain-chroma) (6.33.6)
# Requirement already satisfied: googleapis-common-protos~=1.57 in c:\users\otavi\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.75.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.43.0 in c:\users\otavi\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.43.0)
# Requirement already satisfied: opentelemetry-proto==1.43.0 in c:\users\otavi\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.43.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.64b0 in c:\users\otavi\anaconda3\lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.64b0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\otavi\anaconda3\lib\site-packages (from pydantic-settings>=2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.1.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\otavi\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (3.4.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\otavi\anaconda3\lib\site-packages (from rich>=10.11.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\otavi\anaconda3\lib\site-packages (from rich>=10.11.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\otavi\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.1.2)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\otavi\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.7.1)
# Requirement already satisfied: watchfiles>=0.20 in c:\users\otavi\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.2.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\otavi\anaconda3\lib\site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (3.3.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_chroma import Chroma

embeddings = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)

db = Chroma.from_documents(
    documents=chunks,
    embedding=embeddings,
    persist_directory="chroma_db"
)
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]

# %%
db = Chroma(
    persist_directory="chroma_db",
    embedding_function=embeddings
)
